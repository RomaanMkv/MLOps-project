# %% [markdown]
# # business and data understanding
# ------------
#
# The initial phase is concerned with tasks to define the business objectives and translate it to ML objectives, to collect and verify the data quality and to finaly assess the project feasibility.

# %% [markdown]
# ![](https://i.imgur.com/55J7fBc.jpeg)

# %% [markdown]
# ## Terminology
#
# ### tasks
#
# Compile a glossary of terminology relevant to the project. This may include two components:
# (1) A glossary of relevant business terminology, which forms part of the business understanding available to the project. Constructing this glossary is a useful "knowledge elicitation" and education exercise.
# (2) A glossary of machine learning terminology, illustrated with examples relevant to the business problem in question.
#
# ### output
#
# ### 1. Business Terminology
#
# #### Key Business Terms for the HDB Resale Price Prediction Project
#
# | Term | Definition |
# |------|------------|
# | **HDB (Housing & Development Board)** | A statutory board in Singapore responsible for public housing policies, including the development and management of HDB flats. |
# | **Resale Price** | The price at which an HDB flat is sold on the secondary market, after its initial purchase from the Housing & Development Board (HDB). |
# | **Flat Type** | Classification of HDB flats based on size and layout, such as 2-room, 3-room, 4-room, and 5-room flats. |
# | **Town** | The locality or district in Singapore where the HDB flat is situated. |
# | **Floor Area (sqm)** | The total internal floor space of the flat, measured in square meters. |
# | **Flat Model** | The design type of the flat, such as Improved, New Generation, or Model A. |
# | **Lease Commencement Date** | The year the lease of the HDB flat started, typically lasting 99 years. |
# | **Remaining Lease** | The duration left on the lease of the HDB flat. |
# | **Storey Range** | The range of floors within the building where the flat is located, often expressed as a range (e.g., 01 to 03). |
# | **Market Segmentation** | Dividing the market into distinct groups of buyers with different needs or characteristics. |
# | **Investment Decision** | The process of making choices about where to allocate resources in buying or selling property. |
# | **Targeted Marketing** | Marketing strategies aimed at specific segments of the market to improve efficiency and effectiveness. |
#
# ### 2. Machine Learning Terminology
#
# #### Key ML Terms for the HDB Resale Price Prediction Project
#
# | Term | Definition |
# |------|------------|
# | **Regression Model** | A type of statistical model used to predict a continuous outcome variable based on one or more predictor variables. |
# | **Feature** | An individual measurable property or characteristic used as input to a machine learning model. |
# | **Target Variable** | The outcome variable that the model aims to predict. |
# | **Training Data** | The subset of data used to train the machine learning model, helping it learn the relationship between features and the target variable. |
# | **Test Data** | The subset of data used to evaluate the model’s performance and measure its accuracy. |
# | **Overfitting** | When a model learns the training data too well, including noise, resulting in poor performance on new data. |
# | **Underfitting** | When a model is too simple to capture the underlying patterns in the data, leading to poor performance. |
# | **Cross-Validation** | A technique for assessing how a model generalizes to an independent dataset, typically by splitting the data into multiple training and testing sets. |
# | **Feature Engineering** | The process of creating new features or modifying existing ones to improve model performance. |
# | **Hyperparameters** | Parameters of the model that are set before the learning process begins and govern the training process. |
# | **RMSE (Root Mean Squared Error)** | A metric for evaluating the accuracy of regression models, representing the square root of the average squared differences between predicted and actual values. |
# | **R² (Coefficient of Determination)** | A metric that indicates the proportion of the variance in the target variable that is predictable from the features. |
# | **Regularization** | A technique used to prevent overfitting by adding a penalty for larger coefficients in the regression model. |
# | **Gradient Descent** | An optimization algorithm used to minimize the loss function of a model by iteratively adjusting the model parameters. |
# | **Residuals** | The differences between observed and predicted values in a regression model, used to assess model accuracy. |
# | **Data Preprocessing** | The process of cleaning and transforming raw data into a suitable format for modeling. |
# | **Geospatial Analysis** | Analysis that involves geographic data and spatial relationships. |
# | **Geocoding** | The process of converting addresses into geographic coordinates (latitude and longitude). |

# %% [markdown]
# ## Scope of the project
# ----------
#
# ### tasks
# - Explore the background of the business.
# - Define business problem
# - Define business objectives
# - Translate business objectives into ML objectives
#
# The objective here is to thoroughly understand, from a business perspective, what the client really wants to accomplish. Often the client has many competing objectives and constraints that must be properly balanced. The goal is to uncover important factors, at the beginning, that can influence the outcome of the project. A possible consequence of neglecting this step is to expend a great deal of effort producing the right answers to the wrong questions.
#
# ### output
#
# ### Scope of the Project
#
# ### Tasks
#
# 1. **Explore the Background of the Business:**
#    - Gather information about the organization and its operational context.
#    - Understand the market in which the organization operates.
#    - Identify key stakeholders and their roles.
#
# 2. **Define the Business Problem:**
#    - Clearly articulate the core business issue that needs to be addressed.
#    - Understand the impact of the problem on the business.
#    - Identify any constraints or limitations that the business faces in addressing the problem.
#
# 3. **Define Business Objectives:**
#    - Establish the primary goals that the business wants to achieve.
#    - Identify any secondary objectives or questions that may be relevant.
#    - Consider the broader business context and how achieving these objectives will benefit the organization.
#
# 4. **Translate Business Objectives into ML Objectives:**
#    - Define how machine learning can be used to achieve the business objectives.
#    - Specify the types of predictions or insights needed from the ML models.
#    - Outline the scope of data and the expected outputs of the ML process.
#
# ### Output
#
# #### 1. Background
#
# The organization, HDB, is responsible for public housing in Singapore. They provide affordable housing options for a significant portion of the Singaporean population. HDB flats are sold under a lease system, and a robust secondary market exists for these flats. This resale market is crucial for stakeholders, including buyers, sellers, and investors, who rely on accurate pricing to make informed decisions. As of now, the organization seeks to leverage data on HDB resale transactions to enhance decision-making processes and improve market efficiency. The dataset contains detailed transaction records from January 2017 to June 2024, including information on transaction month, town, flat type, storey range, and resale price.
#
# #### 2. Business Problem
#
# The primary business problem is the need for accurate predictions of HDB flat resale prices. Stakeholders, including potential buyers, sellers, and investors, require reliable price estimates to make informed decisions in the housing market. Currently, price estimation relies heavily on market knowledge and simple comparative methods, which may not account for the complex interactions of various factors influencing resale prices. There is also a need for improved market segmentation to allow for more targeted marketing and sales strategies. This project aims to provide a more sophisticated, data-driven approach to predicting resale prices, thereby enhancing decision-making and market efficiency.
#
# #### 3. Business Objectives
#
# - **Primary Objective:** Develop a predictive model to accurately estimate the resale prices of HDB flats based on available transaction data and property characteristics.
# - **Secondary Objectives:**
#   - Determine how different features, such as flat type, location, floor area, and remaining lease, impact resale prices.
#   - Identify trends and patterns in the HDB resale market over time.
#   - Enable better market segmentation by understanding price dynamics across different towns and flat types.
#   - Provide insights into the geographic distribution of resale prices using geospatial data.
#   - Support targeted marketing efforts by categorizing properties based on price predictions.
#
# #### 4. ML Objectives
#
# - **Predict Resale Prices:** Build a regression model to predict the resale price of HDB flats using features such as transaction month, town, flat type, block, street name, storey range, floor area, flat model, lease commencement date, and remaining lease.
# - **Feature Importance Analysis:** Analyze and identify which features most significantly impact resale prices to provide actionable insights.
# - **Temporal Trends Analysis:** Explore the temporal patterns in the resale market to understand how prices evolve over time.
# - **Geospatial Insights:** Incorporate geospatial analysis to visualize and understand the geographic distribution of resale prices and identify spatial trends.
# - **Price Segmentation:** Develop methods to categorize properties into different price segments based on predicted values, supporting targeted marketing strategies.

# %% [markdown]
# ## Success Criteria
# -------------
#
# ### tasks
# - Describe the success criteria of the ML project on three different levels: the business success criteria, the ML success criteria and the economic success criteria.
#
# ### output
#
# ### Success Criteria
#
# ### Tasks
#
# 1. **Describe the Business Success Criteria:**
#    - Define what successful outcomes look like from a business perspective.
#    - Identify specific, measurable goals that align with the organization's strategic objectives.
#
# 2. **Describe the ML Success Criteria:**
#    - Establish technical benchmarks and performance metrics for the machine learning model.
#    - Specify the desired level of accuracy, precision, or other relevant metrics that indicate successful model performance.
#
# 3. **Describe the Economic Success Criteria:**
#    - Determine the financial or economic impacts that signify success.
#    - Identify cost savings, revenue increases, or other economic benefits expected from the project.
#
# ### Output
#
# #### 1. Business Success Criteria
#
# | Criteria | Description |
# |----------|-------------|
# | **Accurate Resale Price Predictions** | The model should predict HDB resale prices with high accuracy, reducing the average prediction error to less than 5% compared to actual resale prices. |
# | **Improved Decision-Making** | The model’s predictions should enhance stakeholders' ability to make informed buying, selling, and investment decisions, leading to increased customer satisfaction and confidence in market transactions. |
# | **Enhanced Market Segmentation** | Using the model’s outputs, HDB should be able to identify distinct segments in the resale market and tailor marketing strategies effectively, resulting in more targeted and efficient marketing efforts. |
# | **Identification of Market Trends** | The analysis should uncover key trends and patterns in the HDB resale market, providing valuable insights that can inform future business strategies and policy decisions. |
# | **Geospatial Analysis Capabilities** | The project should successfully incorporate geospatial data, enabling the visualization of geographic trends and the spatial distribution of resale prices across different regions. |
#
# #### 2. ML Success Criteria
#
# | Criteria | Description |
# |----------|-------------|
# | **Model Accuracy** | The regression model should achieve a high level of predictive accuracy, ideally with a Root Mean Squared Error (RMSE) of less than 300000 Singapore Dollar on the test data. |
# | **Model Generalization** | The model should generalize well to new, unseen data, as demonstrated by consistent performance across various cross-validation folds and test sets. |
# | **Feature Importance Insight** | The model should provide clear insights into which features most significantly influence resale prices, allowing stakeholders to understand the driving factors behind price variations. |
# | **Temporal Stability** | The model should be robust over different time periods, indicating its ability to handle changes in market conditions and maintain performance over time. |
# | **Geospatial Accuracy** | When incorporating geographic data, the model should accurately reflect spatial trends and correlations in the resale prices. |
# | **Interpretability** | The model should be interpretable, meaning that stakeholders can understand how it makes predictions and the rationale behind its outputs. This is crucial for trust and adoption of the model’s insights. |
#
# #### 3. Economic Success Criteria
#
# | Criteria | Description |
# |----------|-------------|
# | **Cost Efficiency** | The project should reduce the need for extensive manual market analysis and consultancy, leading to cost savings in operational and advisory expenses. |
# | **Increased Revenue** | By providing more accurate price predictions and better market segmentation, the project should contribute to increased revenue through more effective sales and marketing strategies. |
# | **Return on Investment (ROI)** | The project should deliver a positive ROI, calculated as the financial benefits derived from the model (such as cost savings and increased revenue) outweighing the costs of developing and implementing the model. |
# | **Market Competitiveness** | The ability to accurately predict resale prices and understand market trends should improve HDB's competitive positioning in the housing market, attracting more buyers and sellers to use their services. |
# | **Resource Allocation** | Efficient resource allocation in marketing and sales efforts, guided by the model’s insights, should result in better utilization of financial and human resources. |

# %% [markdown]
# ## Data collection
#
# ### tasks
# - Specify the data sources
# - Collect the data
# - Version control on the data
#
# ### output
#
# Based on the provided images and additional information, let's outline the data collection and version control aspects for the HDB resale price prediction project.
#
# ## Data Collection
#
# ### Tasks
#
# 1. **Specify the Data Sources:**
#    - Identify all sources of data required for the project.
#    - Define the type and structure of data available from these sources.
#
# 2. **Collect the Data:**
#    - Implement methods to retrieve the data from the specified sources.
#    - Ensure the data collected meets the project's quality and completeness requirements.
#
# 3. **Version Control on the Data:**
#    - Establish a system to manage changes and updates to the data.
#    - Implement processes for backing up and archiving data, as well as controlling access.
#
# ### Output
#
# #### 1. Data Collection Report
#
# | Aspect | Description |
# |--------|-------------|
# | **Data Source** | The dataset was sourced from [data.gov.sg](https://data.gov.sg/), which is the Singapore government's open data portal. It contains comprehensive records of HDB flat resale transactions from January 2017 to June 2024. |
# | **Data Type** | The dataset includes both numerical and categorical data. **Numerical Data:** Floor area in square meters, lease commencement date, remaining lease in years and months, resale price in Singapore dollars. **Categorical Data:** Transaction month, town, flat type, block, street name, storey range, and flat model. |
# | **Data Size** | The dataset comprises approximately 181,000 rows and 11 columns, covering transactions from January 1, 2017, to June 1, 2024. |
# | **Data Collection Method** | The data was downloaded directly from data.gov.sg in CSV format. To enhance the dataset with geographic coordinates, geocoding services like Google Maps API and Singapore's OneMap API can be used to convert street names into latitude and longitude coordinates. This enables spatial analysis of resale prices. |
#
# #### 2. Data Version Control Report
#
# | Aspect | Description |
# |--------|-------------|
# | **Data Version** | The dataset follows a versioning scheme to track changes and updates. The initial dataset version is v1.0, corresponding to the data as of June 1, 2024. Future updates and modifications will be tracked with subsequent versions, such as v1.1, v1.2, etc. |
# | **Data Change Log** | All changes to the dataset are recorded in a change log. This includes additions of new data, updates to existing records, and any modifications to data structure. For instance, v1.1 might include updated records or new features like geocoded coordinates. The log details the date, nature, and reasons for each change. |
# | **Data Backup** | Regular backups are performed to safeguard against data loss. The dataset is backed up daily and stored securely on a cloud server. This ensures that in the event of data corruption or loss, a recent version of the data can be restored. |
# | **Data Archiving** | Historical versions of the dataset are archived for long-term storage. Data older than a year or replaced by newer versions is archived in a cloud storage service. This facilitates retrieval for historical analysis or rollback if needed. |
# | **Data Access Control** | Access to the dataset is controlled using role-based permissions. Only authorized personnel can view or modify the data, ensuring data integrity and security. Access logs are maintained to track who accessed the data and when, providing a clear audit trail. |

# %% [markdown]
# #### 1. Data Description
#
# The dataset includes records of HDB resale transactions from January 2017 to June 2024. The data is in CSV format and contains 181,000 records with 11 fields.
#
# | Field               | Description                                           |
# |---------------------|-------------------------------------------------------|
# | **month**           | The month when the transaction occurred               |
# | **town**            | The residential area where the flat is located        |
# | **flat_type**       | The classification of the flat based on the number of rooms |
# | **block**           | The block number of the flat                          |
# | **street_name**     | The street where the flat is located                  |
# | **storey_range**    | The range of floors where the flat is situated        |
# | **floor_area_sqm**  | The total interior space of the flat in square meters |
# | **flat_model**      | The design model of the flat                          |
# | **lease_commencement_date** | The year the lease started                           |
# | **remaining_lease** | The remaining duration of the lease in years and months |
# | **resale_price**    | The transaction price of the flat in Singapore dollars |

# %% [markdown]
# Based on data description, we can categorize the features in the following way:
#
# | Field                   | Type         |
# |-------------------------|--------------|
# | month                   | Datetime     |
# | town                    | Categorical  |
# | flat_type               | Categorical  |
# | block                   | Categorical  |
# | street_name             | Categorical  |
# | storey_range            | Categorical  |
# | floor_area_sqm          | Numerical    |
# | flat_model              | Categorical  |
# | lease_commence_date | Datetime     |
# | remaining_lease         | Datetime     |
# | resale_price            | Numerical    |

# %% [markdown]
# #### 2. Data Exploration

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data_path = '../data/samples/sample.csv'
df = pd.read_csv(data_path)

# Display the first few rows of the dataframe
df.head()
# Out:
#      month       town flat_type block      street_name storey_range  \
# 0  2023-08  WOODLANDS    4 ROOM  571B  WOODLANDS AVE 1     10 TO 12
# 1  2018-07  WOODLANDS    4 ROOM   524  WOODLANDS DR 14     04 TO 06
# 2  2018-07   TAMPINES    3 ROOM   405   TAMPINES ST 41     10 TO 12
# 3  2017-11  SEMBAWANG    5 ROOM   315  SEMBAWANG VISTA     10 TO 12
# 4  2017-02    PUNGGOL    5 ROOM  173D    PUNGGOL FIELD     10 TO 12
#
#    floor_area_sqm         flat_model  lease_commence_date     remaining_lease  \
# 0            92.0            Model A                 2013  89 years 03 months
# 1           102.0  Premium Apartment                 2000  80 years 08 months
# 2            69.0           Improved                 1985  66 years 04 months
# 3           121.0           Improved                 1999  80 years 03 months
# 4           110.0           Improved                 2003  85 years 08 months
#
#    resale_price
# 0      550000.0
# 1      349000.0
# 2      325000.0
# 3      478000.0
# 4      453000.0

# %%
# Quantity of the data
data_quantity = df.shape
print(f"Number of rows = {data_quantity[0]}\nNumber of columns = {data_quantity[1]}")
# Out:
# Number of rows = 36253
# Number of columns = 11

# %%
# Data types of the features
data_types = df.dtypes
print("Data types of each feature:\n", data_types)
# Out:
# Data types of each feature:
#  month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %%
# Describe the data to understand the basic statistics
df.describe(include='all')
# Out:
#           month      town flat_type  block     street_name storey_range  \
# count     36253     36253     36253  36253           36253        36253
# unique       90        26         7   2651             562           17
# top     2021-08  SENGKANG    4 ROOM      1  YISHUN RING RD     04 TO 06
# freq        554      2939     15225    119             511         8365
# mean        NaN       NaN       NaN    NaN             NaN          NaN
# std         NaN       NaN       NaN    NaN             NaN          NaN
# min         NaN       NaN       NaN    NaN             NaN          NaN
# 25%         NaN       NaN       NaN    NaN             NaN          NaN
# 50%         NaN       NaN       NaN    NaN             NaN          NaN
# 75%         NaN       NaN       NaN    NaN             NaN          NaN
# max         NaN       NaN       NaN    NaN             NaN          NaN
#
#         floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# count     36253.000000      36253         36253.000000               36253
# unique             NaN         21                  NaN                 655
# top                NaN    Model A                  NaN  94 years 10 months
# freq               NaN      12623                  NaN                 322
# mean         97.247472        NaN          1995.983670                 NaN
# std          24.111761        NaN            14.041367                 NaN
# min          31.000000        NaN          1966.000000                 NaN
# 25%          82.000000        NaN          1985.000000                 NaN
# 50%          93.000000        NaN          1996.000000                 NaN
# 75%         112.000000        NaN          2010.000000                 NaN
# max         208.000000        NaN          2020.000000                 NaN
#
#         resale_price
# count   3.625300e+04
# unique           NaN
# top              NaN
# freq             NaN
# mean    4.992109e+05
# std     1.734134e+05
# min     1.500000e+05
# 25%     3.700000e+05
# 50%     4.690000e+05
# 75%     5.950000e+05
# max     1.450000e+06

# %%
# Distribution of each data feature
for feature in df.columns:
    if pd.api.types.is_numeric_dtype(df[feature]):
        plt.figure(figsize=(5, 3))
        sns.histplot(df[feature], kde=True)
    elif pd.api.types.is_datetime64_any_dtype(df[feature]):
        sns.histplot(df[feature].dt.year, kde=True)
    elif df[feature].nunique() <= 30:
        plt.figure(figsize=(8, 5))
        sns.countplot(y=df[feature], order=df[feature].value_counts().index)
    else:
        print(f"Skipping countplot for {feature} as it has more than 20 unique values.")
        continue
    plt.title(f'Distribution of {feature}')
    plt.show()
# Out:
# Skipping countplot for month as it has more than 20 unique values.
# Skipping countplot for block as it has more than 20 unique values.
# Skipping countplot for street_name as it has more than 20 unique values.
# Skipping countplot for remaining_lease as it has more than 20 unique values.

# %%
# Bivariate analysis - relationship of each feature with the target (resale_price)
numerical_features = ['floor_area_sqm', 'lease_commence_date']
categorical_features = ['town', 'flat_type', 'storey_range', 'flat_model']

for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=df[feature], y=df['resale_price'])
    plt.title(f'Relationship between {feature} and resale_price')
    plt.show()

# %%
for feature in categorical_features:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[feature], y=df['resale_price'])
    plt.xticks(rotation=90)
    plt.title(f'Relationship between {feature} and resale_price')
    plt.show()

# %% [markdown]
# ##### Data Features Needing Cleaning
#
# Data has already been cleaned, so we do not need cleaning
#
# ##### Quantity of the Data
#
# - **Number of rows:** 36,253
# - **Number of columns:** 11
#
# ##### Categories of Feature Types
#
# - **Categorical Features:** town, flat_type, block, street_name, storey_range, flat_model
# - **Numerical Features:** floor_area_sqm, lease_commence_date, resale_price
# - **Datetime Features:** month, remaining_lease
#
# ##### Distribution of Each Data Feature and the Target
#
# - The distributions for the numerical and categorical features were visualized using histograms and boxplots.
# - The target variable `resale_price` shows a skewed distribution with a peak around SGD 400,000 to SGD 500,000.
#
# ##### Bivariate Analysis
#
# - **Linear Relationships:**
#   - `floor_area_sqm` shows a positive linear relationship with `resale_price`.
#   - `lease_commence_date` has a somewhat linear relationship with `resale_price`.
#
# - **Categorical Relationships:**
#   - `flat_model`, `flat_type`, `storey_range`, and `town` show clear distinctions in `resale_price` distributions.
#
# #### Conclusions on Relationships
#
# - There are clear linear relationships between certain numerical features (`floor_area_sqm`, `lease_commence_date`) and the target (`resale_price`).
# - Categorical features also show significant impact on `resale_price`, as seen from the boxplots.
#
# #### Suggested ML Methods
#
# - **Useful ML Methods:**
#   - **Linear Regression:** Suitable for capturing linear relationships.
#   - **Decision Trees/Random Forests:** Effective in handling both numerical and categorical data.
#   - **Gradient Boosting Machines:** Useful for capturing complex patterns and interactions.
#
# - **Not Useful ML Methods:**
#   - **K-Nearest Neighbors (KNN):** Less effective due to high-dimensional categorical data and potential scaling issues.
#   - **Support Vector Machines (SVM):** May not perform well with large datasets and mixed data types.
#
# #### Preliminary Set of Features for ML Model
#
# - **Numerical Features:** `floor_area_sqm`, `lease_commence_date`
# - **Categorical Features:** `town`, `flat_type`, `storey_range`, `flat_model`
#
# #### Data Transformation Methods for ML-Ready Datasets
#
# **Features Needing Transformation:**
# - Categorical features (`town`, `flat_type`, `storey_range`, `flat_model`): Require one-hot encoding.
# - Numerical features: Require scaling.
# - Datetime features: Convert `month` to `datetime` and extract useful components.
#
# **Transformation Types:**
# - **One-Hot Encoding:** Convert categorical features into binary vectors.
# - **Normalization/Standardization:** Scale numerical features.

# %% [markdown]
# #### 3. Data Quality verification

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per feature:\n", missing_values)
# Out:
# Missing values per feature:
#  month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %% [markdown]
# ##### Features Needing Imputation/Handling
#
# Since there are no missing values in the dataset, there is no need for imputation or handling of missing values.
#
# ##### Handling of Missing Features
#
# As the dataset has no missing values, no handling is required.
#
# ##### Quality of the Data
#
# - **Quality of the Data:** Excellent
#   - The dataset is complete with no missing values.
#   - The features are well-defined and appear to be consistent.

# %% [markdown]
# #### 4. Data requirements

# %%
import numpy
numpy.strings = None
numpy.char = None
import great_expectations as gx
from great_expectations.data_context import FileDataContext

# Initialize the DataContext
FileDataContext(project_root_dir = "../services")
context = gx.get_context(project_root_dir = "../services")

# Add or update the pandas datasource
ds = context.sources.add_or_update_pandas(name = "pandas_datasource")

# Add CSV asset
da1 = ds.add_csv_asset(
    name = "csv_file",
    filepath_or_buffer="../data/samples/sample.csv",
)

# Build batch request
batch_request = da1.build_batch_request()
batches = da1.get_batch_list_from_batch_request(batch_request)

# Add or update the expectation suite
context.add_or_update_expectation_suite("initial_data_validation")

# Get validator for the batch and expectation suite
validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name="initial_data_validation"
)

# 1. 'month' feature
validator.expect_column_values_to_not_be_null('month')
validator.expect_column_values_to_be_between('month', min_value='2017-01', max_value='2024-06')
validator.expect_column_values_to_match_regex('month', r'^\d{4}-\d{2}$')

# 2. 'town' feature
validator.expect_column_values_to_not_be_null('town')
validator.expect_column_values_to_be_in_set('town', [
    'ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH', 'BUKIT PANJANG', 'BUKIT TIMAH',
    'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
    'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL', 'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG',
    'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN'
])

# 3. 'flat_type' feature
validator.expect_column_values_to_not_be_null('flat_type')
validator.expect_column_values_to_be_in_set('flat_type', ['1 ROOM', '2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', 'MULTI-GENERATION'])

# 4. 'storey_range' feature
validator.expect_column_values_to_not_be_null('storey_range')
validator.expect_column_values_to_be_in_set('storey_range', [
    '01 TO 03', '04 TO 06', '07 TO 09', '10 TO 12', '13 TO 15', '16 TO 18', '19 TO 21', '22 TO 24', '25 TO 27',
    '28 TO 30', '31 TO 33', '34 TO 36', '37 TO 39', '40 TO 42', '43 TO 45', '46 TO 48', '49 TO 51'
])

# 5. 'floor_area_sqm' feature
validator.expect_column_values_to_not_be_null('floor_area_sqm')
validator.expect_column_values_to_be_between('floor_area_sqm', min_value=31, max_value=249)
validator.expect_column_values_to_match_regex('floor_area_sqm', r'^\d+(\.\d+)?$')

# 6. 'lease_commence_date' feature
validator.expect_column_values_to_not_be_null('lease_commence_date')
validator.expect_column_values_to_be_between('lease_commence_date', min_value=1966, max_value=2020)
validator.expect_column_values_to_match_regex('lease_commence_date', r'^\d{4}$')

# 7. 'resale_price' feature
validator.expect_column_values_to_not_be_null('resale_price')
validator.expect_column_values_to_be_between('resale_price', min_value=140000, max_value=1588000)
validator.expect_column_pair_values_A_to_be_greater_than_B('resale_price', 'floor_area_sqm')

# 8. 'flat_model' feature
validator.expect_column_values_to_not_be_null('flat_model')
validator.expect_column_values_to_be_in_set('flat_model', [
    'Model A', 'Improved', 'New Generation', 'DBSS', 'Simplified', 'Apartment', 'Standard', 'Premium Apartment',
    'Maisonette', 'Model A-Maisonette', 'Premium Apartment Loft', 'Type S1', 'Type S2', 'Model A2', '2-room',
    'Terrace', 'Adjoined flat', 'Improved-Maisonette', 'Multi Generation', '3Gen', 'Premium Maisonette'
])

# 9. 'block' feature
validator.expect_column_values_to_not_be_null('block')

# Save the expectation suite
validator.save_expectation_suite()

# Validate the batch
results = validator.validate()
print(results.success)

for result in results['results']:
    expectation = result['expectation_config']['expectation_type']
    success = result['success']
    if success:
        print(f"Expectation {expectation}: SUCCESS")
    else:
        print(f"Expectation {expectation}: FAILURE")
        print(f"Details: {result['result']}")
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/67 [00:00<?, ?it/s]
# True
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_between: SUCCESS
# Expectation expect_column_values_to_match_regex: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_in_set: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_in_set: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_in_set: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_between: SUCCESS
# Expectation expect_column_values_to_match_regex: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_between: SUCCESS
# Expectation expect_column_values_to_match_regex: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_between: SUCCESS
# Expectation expect_column_pair_values_a_to_be_greater_than_b: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS
# Expectation expect_column_values_to_be_in_set: SUCCESS
# Expectation expect_column_values_to_not_be_null: SUCCESS

# %% [markdown]
# #### Data Quality Dimensions:
# The data quality dimensions covered in this report include completeness, uniqueness, timeliness, validity, consistency, and accuracy.
#
# #### Data Requirements for Critical Features
#
# 1. **`month` Feature**
#    - **Completeness:** There should be no missing values in the `month` column.
#    - **Timeliness:** The values in the `month` column should be within the range of January 2017 to June 2024.
#    - **Validity:** The values in the `month` column should match the format `YYYY-MM`.
#
# 2. **`town` Feature**
#    - **Completeness:** There should be no missing values in the `town` column.
#    - **Uniqueness:** The values in the `town` column should exist within a predefined set of known town names.
#    - **Validity:** The values in the `town` column should be one of the known town names.
#
# 3. **`flat_type` Feature**
#    - **Completeness:** There should be no missing values in the `flat_type` column.
#    - **Validity:** The values in the `flat_type` column should be one of the known flat types (e.g., 1 ROOM, 2 ROOM, etc.).
#    - **Consistency:** The values in the `flat_type` column should be consistent with other related features, such as `floor_area_sqm`.
#
# 4. **`storey_range` Feature**
#    - **Completeness:** There should be no missing values in the `storey_range` column.
#    - **Validity:** The values in the `storey_range` column should be within the known ranges (e.g., 01 TO 03, 04 TO 06, etc.).
#    - **Consistency:** The values in the `storey_range` column should logically align with the values in the `flat_type` column.
#
# 5. **`floor_area_sqm` Feature**
#    - **Completeness:** There should be no missing values in the `floor_area_sqm` column.
#    - **Validity:** The values in the `floor_area_sqm` column should be between 31 and 249.
#    - **Accuracy:** The values in the `floor_area_sqm` column should be numeric and match the format for floating-point numbers.
#
# 6. **`lease_commence_date` Feature**
#    - **Completeness:** There should be no missing values in the `lease_commence_date` column.
#    - **Timeliness:** The values in the `lease_commence_date` column should be within the range of 1966 to 2020.
#    - **Accuracy:** The values in the `lease_commence_date` column should be numeric and represent valid years.
#
# 7. **`resale_price` Feature**
#    - **Completeness:** There should be no missing values in the `resale_price` column.
#    - **Validity:** The values in the `resale_price` column should be between SGD 140,000 and SGD 1,588,000.
#    - **Consistency:** The values in the `resale_price` column should logically align with the values in the `floor_area_sqm` column.
# 8. **`flat_model` Feature**
#    - **Completeness:** There should be no missing values in the `flat_model` column.
#    - **Validity:** The values in the `resale_price` column should be one of the known flat models (e.g., Model A, Apartment, etc.)
# 9. **`block` Feature**
#    - **Completeness:** There should be no missing values in the `block` column.

# %% [markdown]
# ## Project feasibility
# -------------
# This task involves more detailed fact-finding about all of the resources,constraints, assumptions and other factors that should be considered in determining the data analysis goal and project plan. In the previous task, your objective is to quickly get to the crux of the situation. Here, you want to flesh out the details.
#
# ### tasks
# - Assess the project feasibility
# - Create POC (Proof-of-concept) model
#
# ### output
#
# ### 1. Inventory of Resources
#
# #### Personnel
#
# 1. **Data Experts:**
#    - **Data Analysts:** Professionals skilled in data exploration, preprocessing, and statistical analysis.
#    - **Data Engineers:** Technicians responsible for data acquisition, storage, and management.
#
# 2. **Machine Learning Personnel:**
#    - **Data Scientists:** Experts in developing and tuning machine learning models, including data preparation, feature engineering, and model evaluation.
#    - **ML Engineers:** Specialists in deploying, monitoring, and maintaining machine learning models in production environments.
#
# #### Data
#
# 1. **Fixed Extracts:**
#    - **Historical HDB Resale Data:** CSV file containing 36,253 rows and 11 columns from January 2017 to June 2024, sourced from data.gov.sg.
#    - **Supplementary Geospatial Data:** Data from APIs like Google Maps and OneMap for converting addresses into geographic coordinates.
#
# #### Computing Resources
#
# 1. **Hardware Platforms:**
#    - **Cloud Computing Services**
#    - **On-Premises Servers (local machines)**
#
# 2. **Software:**
#    - **Machine Learning Tools:** Libraries and frameworks such as Scikit-Learn, TensorFlow, and XGBoost for developing and training models.
#    - **Data Processing Tools:** Software like Pandas and NumPy for data manipulation and analysis.
#    - **Visualization Tools:** Tools like Matplotlib, Seaborn, and Plotly for data visualization and exploratory analysis.
#    - **Geospatial Tools:** APIs and libraries for geocoding and spatial analysis, including Google Maps API and GeoPandas.
#
# ---
#
# ### 2. Requirements, Assumptions, and Constraints
#
# #### Requirements
#
# 1. **Schedule of Completion:**
#    - **Initial Model Development:** Complete within 1 week.
#    - **Deployment and Integration:** Complete within 2-3 weeks.
#    - **Ongoing Model Updates:** Regular updates on a weekly basis.
#
# 2. **Comprehensibility and Quality of Results:**
#    - **Model Interpretability:** The models should provide insights into how predictions are made, with feature importance and clear explanations.
#    - **Accuracy Metrics:** The model should achieve a performance benchmark, such as an RMSE of less than SGD 30,000 and an R² above 0.80.
#
# 3. **Security and Legal Issues:**
#    - **Data Privacy:** Ensure compliance with data protection regulations, such as PDPA (Personal Data Protection Act) in Singapore.
#    - **Data Usage Rights:** Confirm that the data from data.gov.sg and geospatial APIs can be legally used for this purpose.
#
# #### Assumptions
#
# 1. **Data Assumptions:**
#    - **Data Completeness:** The dataset from data.gov.sg is assumed to be comprehensive and up-to-date for the period it covers.
#    - **Data Quality:** The provided data is accurate and reliable for model training and evaluation.
#    - **Geocoding Accuracy:** The geographic coordinates obtained from APIs will accurately reflect the locations of the HDB flats.
#
# 2. **Business Assumptions:**
#    - **Market Stability:** The factors influencing HDB resale prices remain consistent over the modeling period.
#    - **User Adoption:** Stakeholders will actively use the predictive system and integrate its outputs into their decision-making processes.
#
# #### Constraints
#
# 1. **Resource Availability:**
#    - **Computing Resources:** Limitations on the availability and budget for cloud computing and storage resources.
#    - **Personnel Time:** ***CONSTRAINTS ON THE AVAILABILITY OF SKILLED PERSONNEL DUE TO OTHER ONGOING PROJECTS OR LIMITED TEAM SIZE**.
#
# 2. **Technological Constraints:**
#    - **Data Size:** Practical limitations on the size of the dataset that can be handled for modeling, especially when dealing with high-dimensional data.
#    - **Integration Complexity:** Challenges in integrating the predictive models into existing systems and workflows.
#
# ---
#
# ### 3. Risks and Contingencies
#
# #### Risks
#
# 1. **Data Quality Issues:**
#    - **Inaccurate or Incomplete Data:** Poor data quality could lead to unreliable models.
#    - **Contingency:** Implement robust data validation and cleaning processes. Regularly review data sources for updates or corrections.
#
# 2. **Model Performance Shortfalls:**
#    - **Underperformance of Models:** Models may fail to meet the desired accuracy metrics.
#    - **Contingency:** Experiment with different algorithms, fine-tune hyperparameters, and enhance feature engineering. Consider ensemble methods to improve performance.
#
# 3. **Resource Limitations:**
#    - **Insufficient Computing Power:** Limited access to computing resources could delay model training and updates.
#    - **Contingency:** Optimize code and use cloud resources efficiently. Prioritize critical tasks and consider acquiring additional resources if budget allows.
#
# 4. **Regulatory and Legal Challenges:**
#    - **Non-compliance with Data Regulations:** Potential issues with data privacy and usage rights.
#    - **Contingency:** Ensure legal review and compliance checks are in place. Seek permissions and clarify usage rights for all data sources.
#
# 5. **Integration and Adoption Issues:**
#    - **Difficulty in System Integration:** Challenges in embedding the predictive models into existing applications.
#    - **Contingency:** Collaborate closely with software development teams and ensure proper documentation and testing. Plan for incremental integration and user training sessions.
#
# 6. **Market Changes:**
#    - **Unforeseen Economic or Policy Changes:** Significant changes in the housing market or policies could render the model less effective.
#    - **Contingency:** Regularly update models and retrain with the latest data. Monitor market conditions and adjust model assumptions and features as needed.
#
#
# ### 4. Feasibility report
#
# #### POC Model Summary
#
# **Model Used:** Linear Regression
# **Data Used:** 1/5 of the dataset focusing on two numerical features (`floor_area_sqm` and `lease_commence_date`)
# **Preprocessing:** No preprocessing or parameter fine-tuning was applied
# **Accuracy Achieved:** 43%
# > ⓘ **Note:**  for aditional information please refer to `PoC.ipynb`.
#
# #### Feasibility Analysis
#
# ##### 1. Data Availability
#
# - **Current Data:**
#   - The dataset from data.gov.sg provides comprehensive historical transaction data for HDB resale prices from January 2017 to June 2024.
#   - The data includes 36,253 rows and 11 columns, with detailed information on flat characteristics, location, and transaction dates.
#
# - **Supplementary Data:**
#   - Additional data, such as geospatial coordinates, can be obtained through APIs like Google Maps and OneMap.
#   - Real-time access to updated transaction data is possible from the same or other operational sources.
#
# - **Conclusion:**
#   - **Feasible**: The data availability is robust, covering a wide range of attributes necessary for building a predictive model.
#
# ##### 2. Data Quality
#
# - **Current Data Quality:**
#   - The data has been cleaned, and preliminary analysis indicates that it is reliable and well-structured.
#   - Key features such as `resale_price`, `floor_area_sqm`, and `lease_commence_date` show meaningful relationships with the target variable.
#
# - **Preprocessing Needs:**
#   - Some features require transformation (e.g., one-hot encoding for categorical variables, scaling for numerical variables).
#   - The datetime feature `month` needs to be converted and decomposed for better temporal analysis.
#
# - **Conclusion:**
#   - **Feasible**: With proper preprocessing and feature engineering, the data quality is adequate for developing a robust ML model.
#
# ##### 3. Nature of Business Problem
#
# - **Business Needs:**
#   - Accurate pricing predictions are crucial for buyers, sellers, and investors in the HDB resale market.
#   - The market's dynamic nature requires a model that can adapt to changes and provide timely, accurate insights.
#
# - **Initial Model Performance:**
#   - The POC model achieved an accuracy of 43% without any preprocessing or parameter tuning, indicating that with more comprehensive feature utilization and fine-tuning, the model performance can be significantly improved.
#
# - **Challenges and Opportunities:**
#   - Challenges include integrating diverse data types and ensuring model interpretability.
#   - Opportunities exist in enhancing market efficiency and providing valuable insights into property valuation.
#
# - **Conclusion:**
#   - **Feasible**: The business problem aligns well with the capabilities of machine learning, and the initial POC shows promise that further development can lead to successful outcomes.
#
# ---
#
# #### Overall Feasibility Conclusion
#
# Given the robust availability and quality of data, the favorable cost-benefit ratio, and the alignment of the business problem with machine learning capabilities, the project to develop a predictive model for HDB resale prices is **feasible**.

# %% [markdown]
# ## produce project plan
# ----------------
#
# ### task
#
# Describe the intended plan for achieving the machine learning goals and thereby achieving the business goals. The plan should specify the anticipated set of steps to be performed during the rest of the project including an initial selection of tools and techniques.
#
# ### output
#
# #### 1. Project plan
# - List the stages to be executed in the project, together with their duration, resources required, inputs, outputs, and dependencies. Where possible, try and make explicit the large-scale iterations in the machine learning process, for example, repetitions of the modeling and evaluation phases. As part of the project plan, it is also important to analyze dependencies between time schedule and risks. Mark results of these analyses explicitly in the project plan, ideally with actions and recommendations if the risks are manifested. Decide at this point which evaluation strategy will be used in the evaluation phase. Your project plan will be a dynamic document. At the end of each phase you’ll review progress and achievements and update the project plan accordingly. Specific review points for these updates should be part of the project plan.
#
# - Build a Gantt chart for the project tasks and phases using some online platforms like TeamGantt, jira, goodday, tello, ...etc
#
# - Add all of your team members and assign tasks to them preliminary. Then you check daily the progress.
#
# #### 2. ML project Canvas
# At the end of the first phase, you should create a canvas for the project as a summary of this phase.
#
#
# > ##### Example
# > Follow the link: https://github.com/louisdorard/machine-learning-canvas/blob/master/churn.pdf

# %% [markdown]
# ML project Canvas is placed in reports folder
